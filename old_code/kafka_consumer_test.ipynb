# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer
from kafka import KafkaConsumer

# %%
producer = KafkaProducer(bootstrap_servers=['54.175.181.170:9092'],
                         value_serializer=lambda x: 
                         dumps(x).encode('utf-8'))

# %%
for e in range(10):
    data = {'number' : e}
    producer.send('test_python_2', value=data)
    sleep(1)

# %%
bootstrap_servers = ['54.175.181.170:9092']
consumer = KafkaConsumer(bootstrap_servers=bootstrap_servers)

# %%
topic_list = list(consumer.topics())

# %%
topic_list
# Out:
# ['bstag-ramya-O360-1866',
#  'stag-dsv2-O360-4176',
#  'stag-pasupathym-O360-910',
#  'stag-basavaraj.aihole12-O360-3828',
#  'stag-basavaraj.aihole12-O360-3798',
#  'test-pentest-O360-8656',
#  'stag-dsv2-O360-3850',
#  'test-spl-O360-7315',
#  'test-korade-O360-7651',
#  'stag-laksp-O360-4029',
#  'test-rinni-O360-3942',
#  'stag-stagetest-O360-2213',
#  'dev-pat3-PATIENTX360-395',
#  'test2',
#  'stag-stagetest-O360-2557',
#  'stag-yashstage-O360-3871',
#  'stag-stagetest-O360-2423',
#  'stag-laksp-O360-3078',
#  'btest-o360p2-O360-7248',
#  'stag-o360pilot-O360-647',
#  'stag-testuserrwhed-O360-2994',
#  'stag-prodo360-O360-3927',
#  'aniO360',
#  'stag-stagetest-O360-2219',
#  'test-spl-O360-7909',
#  'stag-dsv2-O360-4056',
#  'stag-dsv2-O360-4193',
#  'stag-yashstage-O360-3893',
#  'stag-ramya-O360-2186',
#  'rinniO360',
#  'test-user1-PATIENTX360-233',
#  'stag-basavaraj.aihole12-O360-3803',
#  'btest-o360p2-O360-6812',
#  'test-abhinav-O360-7244',
#  'stag-prodo360-O360-3797',
#  'test-abx-O360-8249',
#  'test-chandanam-O360-7481',
#  'o360-testshishirO3606222',
#  'dev-shishir-O360-1',
#  'stag-ostage-O360-4022',
#  'test-o360_user-O360-7592',
#  'stag-stagetest-O360-2215',
#  'stag-basavaraj.aihole12-O360-3813',
#  'prod-ramya_2-O360-1866-12663',
#  'sisense_model',
#  'stag-yashstage-O360-2543',
#  'pmoO360',
#  'stag-dsv2-O360-3624',
#  'stag-dsv2-O360-2020',
#  'stag-testuserpbggw-O360-2887',
#  'stag-yashstage-O360-4120',
#  'stag-dsv-O360-4089',
#  'bstag-stagetest-O360-4215',
#  'test_python_2',
#  'stag-ostage-O360-2788',
#  'test-o360_user-O360-7908',
#  'stag-stagetest-O360-3854',
#  'stag-dsv2-O360-3838',
#  'stag-dsv2-O360-3853',
#  'ishanO360',
#  'stag-laksp-O360-2986',
#  'stag-laksp-O360-3065',
#  'test-amruthavarshinin-O360-7655',
#  'test-o360testuser-O360-7819',
#  'stag-ostage-O360-4020',
#  'test-testuserudyj-O360-7767',
#  'stag-dsv2-O360-3837',
#  'stag-basavaraj.aihole12-O360-3808',
#  'stag-yashstage-O360-3867',
#  'stag-abt-O360-3472',
#  'stag-ramya-O360-3773',
#  'o360_userO360',
#  'stag-kritika-O360-3422',
#  'stag-dsv2-O360-3765',
#  'dsvO360',
#  'stag-dsv2-O360-4179',
#  'test-rjtest-O360-7283',
#  'stag-yashstage-O360-4046',
#  'test-prodo360-O360-8652',
#  'test-abx-O360-7491',
#  'data',
#  'test-o360pilot-O360-751',
#  'prod-ramya_2-O360-1866-12669',
#  'test-yash11-O360-7196',
#  'stag-basavaraj.aihole12-O360-4067',
#  'stag-brimm-O360-4127',
#  'paulpvarghese1978O360',
#  'stag-dsv2-O360-4189',
#  'stag-laksp-O360-2984',
#  'btest-ede-pd-6781',
#  'test-abhinav-O360-7236',
#  'test-nandan-O360-7178',
#  'stag-ani-O360-3181',
#  'dev-pat3-PATIENTX360-252',
#  'test-pasupathym-O360-7273',
#  'stag-basavaraj.aihole12-O360-3805',
#  'stag-testuserbkofg-O360-3106',
#  'prod-ramya_2-O360-1866',
#  'test-ani-O360-6685',
#  'stag-kritika-O360-3199',
#  'btest-o360p2-O360-7375',
#  'test-pentest-O360-8655',
#  'prod-ramya_2-O360-1739',
#  'stag-basavaraj.aihole12-O360-3823',
#  'Producer',
#  'test-pasupathym-O360-7276',
#  'test-paulpvarghese1978-O360-7555',
#  'stag-basavaraj.aihole12-O360-3645',
#  'stag-stagetest-O360-2819',
#  'bstag-ramya-O360-1859',
#  'stag-stagetest-O360-3647',
#  'stag-ramya-O360-1866',
#  'test-korade-O360-7660',
#  'dev-suhas123-O360-2271',
#  'stag-basavaraj.aihole12-O360-3825',
#  'stag-yashstage-O360-3865',
#  'bstag-o360pilot-O360-646',
#  'test-testusernmps-O360-7707',
#  'test-pasupathym-O360-7274',
#  'shishirO360',
#  'stag-laksp-O360-3470',
#  'test-pmo-O360-6555',
#  'stag-stagetest-O360-3061',
#  'stag-yashstage-O360-3879',
#  'bstag-stagetest-O360-3061',
#  'stag-abx-O360-3462',
#  'test-test-O360-10',
#  'stag-ramya-O360-1389',
#  'btest-o360p2-O360-7371',
#  'stag-brimm-O360-4107',
#  'stag-ostage-O360-2539',
#  'test-o360_user-O360-7922',
#  'test-chandanam-O360-7486',
#  'test-basavaraj-O360-7424',
#  'stag-dsv2-O360-3690',
#  'bstag-ramya-O360-2186',
#  'stag-prodo360-O360-3883',
#  'test-o360_user-O360-6989',
#  'prod-ramya_2-O360-1866-12657',
#  'dev-pat3-PATIENTX360-94',
#  'stag-stagetest-O360-4215',
#  'parmesh',
#  'stag-basavaraj.aihole12-O360-4064',
#  'stag-dsv2-O360-4192',
#  'stag-dsv2-O360-4186',
#  'stag-basavaraj.aihole12-O360-3799',
#  'test-basavaraj-O360-7449',
#  'stag-basavaraj.aihole12-O360-3807',
#  'stag-dsv2-O360-3851',
#  'test-basavaraj-O360-7839',
#  'bstag-stagetest-O360-4218',
#  'test-kritika-O360-7553',
#  'stag-testuseraqtpr-O360-2860',
#  'test-o360_user-O360-7907',
#  'stag-basavaraj.aihole12-O360-3875',
#  'test-paulpvarghese1978-O360-6421',
#  'stag-stagetest-O360-2899',
#  'stag-dsv2-O360-4177',
#  'test-yash11-O360-7979',
#  'stag-yashstage-O360-3869',
#  'vatsO360',
#  'stag-ramya-O360-1739',
#  'stag-testuserslvug-O360-2991',
#  'test-o360testuser-O360-7389',
#  'bstag-stagetest-O360-3279',
#  'stag-testuserkeqct-O360-2850',
#  'test-pentest-O360-8658',
#  'stag-basavaraj.aihole12-O360-3644',
#  'stag-laksp-O360-3821',
#  'test-pasupathym-O360-7453',
#  'stag-o360pilot-O360-648',
#  'stag-o360pilot-O360-751',
#  'stag-prodo360-O360-2768',
#  'stag-dsv2-O360-3651',
#  'stag-brimm-O360-4111',
#  'btest-basavaraj-O360-7449',
#  'prod-ramya_2-O360-1866-12666',
#  'stag-testuserkzqoc-O360-2893',
#  'bstag-stagetest-O360-4214',
#  'test-adithya-O360-7518',
#  'stag-o360pilot-O360-646',
#  'stag-ramya-O360-1359',
#  'test-yash11-O360-7988',
#  'stag-basavaraj.aihole12-O360-4023',
#  'test-o360testuser-O360-7818',
#  'stag-stagetest-O360-2211',
#  'paramtestdata',
#  'stag-yashstage-O360-3889',
#  'prod-ramya_2-O360-1739-11821',
#  'stag-yashstage-O360-3886',
#  'test-kritika-O360-7554',
#  'test-yash11-O360-7987',
#  'splakO360',
#  'stag-pasupathym-O360-924',
#  'prod-ramya_2-O360-1866-12661',
#  'stag-ostage-O360-2617',
#  'stag-yashstage-O360-2527',
#  'bstag-stagetest-O360-4216',
#  'stag-ostage-O360-4018',
#  'stag-basavaraj.aihole12-O360-3817',
#  'stag-dsv2-O360-4180',
#  'stag-yashstage-O360-4238',
#  'stag-yashstage-O360-3892',
#  'stag-laksp-O360-3080',
#  'test-ani-O360-6791',
#  'stag-dsv2-O360-4054',
#  'stag-laksp-O360-4211',
#  'stag-dsv2-O360-4191',
#  'stag-stagetest-O360-2818',
#  'stag-dsv2-O360-4183',
#  'btest-o360p2-O360-7303',
#  'stag-o360pilot-O360-645',
#  'inputTopic',
#  'test-test-O360-5',
#  'stag-dsv2-O360-3692',
#  'stag-basavaraj.aihole12-O360-3802',
#  'stag-yashstage-O360-3788',
#  'test-abx-O360-7489',
#  'test-test-O360-11',
#  'stag-dsv2-O360-4055',
#  'test-ani-O360-7687',
#  'test-ani-O360-7686',
#  'test-yash11-O360-7980',
#  'stag-laksp-O360-3820',
#  'stag-ostage-O360-4019',
#  'stag-laksp-O360-2979',
#  'test-korade-O360-7395',
#  'stag-brimm-O360-4126',
#  'test-pentest-O360-8659',
#  'test_kafka_python',
#  'stag-basavaraj.aihole12-O360-3866',
#  'test-testuserjerg-O360-7697',
#  'bstag-stagetest-O360-3647',
#  'test-korade-O360-7650',
#  'stag-dsv2-O360-3652',
#  'stag-basavaraj.aihole12-O360-3646',
#  'stag-basavaraj.aihole12-O360-3902',
#  'test-test-O360-2',
#  'stag-basavaraj.aihole12-O360-3887',
#  'stag-laksp-O360-3471',
#  'test-nandan-O360-7187',
#  'test-chaitra-O360-7471',
#  'test-o360p2-O360-6782',
#  'stag-stagetest-O360-3279',
#  'stag-basavaraj.aihole12-O360-4073',
#  'test-paulpvarghese1978-O360-7466',
#  'test-sourabh-PATIENTX360-234',
#  'stag-yashstage-O360-4043',
#  'stag-dsv2-O360-4182',
#  'stag-dsv2-O360-3691',
#  'stag-basavaraj.aihole12-O360-3819',
#  'stag-basavaraj.aihole12-O360-3816',
#  'stag-testuserpsjui-O360-2821',
#  'stag-testuseroueax-O360-3210',
#  'test-korade-O360-7607',
#  'stag-basavaraj.aihole12-O360-3841',
#  'stag-ani-O360-2544',
#  'test-o360_user-O360-6845',
#  'stag-yashstage-O360-3809',
#  'stag-basavaraj.aihole12-O360-3827',
#  'stag-basavaraj.aihole12-O360-3796',
#  'btest-o360testuser-O360-7818',
#  'stag-dsv2-O360-4173',
#  'stag-basavaraj.aihole12-O360-3829',
#  'test-chaitra-O360-7365',
#  'stag-yashstage-O360-4119',
#  'stag-yashstage-O360-3787',
#  'stag-dsv2-O360-4174',
#  'stag-dsv2-O360-4053',
#  'stag-laksp-O360-3695',
#  'stag-basavaraj.aihole12-O360-3784',
#  'stag-laksp-O360-2980',
#  'stag-basavaraj.aihole12-O360-4065',
#  'stag-testuservwexb-O360-3551',
#  'stag-dsv2-O360-4188',
#  'stag-dsv2-O360-3836',
#  'stag-stagetest-O360-4214',
#  'stag-testusernrdpl-O360-3141',
#  'stag-prodo360-O360-3845',
#  'stag-dsv2-O360-4185',
#  'stag-ostage-O360-2540',
#  'btest-dsv2-O360-7421',
#  'stag-ostage-O360-4139',
#  'dev-pat3-PATIENTX360-223',
#  'stag-stagetest-O360-3197',
#  'stag-basavaraj.aihole12-O360-4071',
#  'test-abhinav-O360-7304',
#  'kritikaO360',
#  'test-paulpvarghese1978-O360-6492',
#  'test-pentest-O360-8661',
#  'stag-yashstage-O360-3908',
#  'stag-laksp-O360-2975',
#  'test-adithya-O360-7522',
#  'stag-ani-O360-2552',
#  'stag-dsv2-O360-4175',
#  'dev-pat3-PATIENTX360-251',
#  'stag-stagetest-O360-4216',
#  'stag-stagetest-O360-4218',
#  'test-adithya-O360-7313',
#  'stag-basavaraj.aihole12-O360-3806',
#  'stag-laksp-O360-3086',
#  'test-shishir-O360-6647',
#  'stag-testuserlqfzb-O360-3352',
#  'test-chandanam-O360-7478',
#  'dev-pat3-PATIENTX360-392',
#  'stag-dsv2-O360-3683',
#  'bstag-stagetest-O360-4217',
#  'stag-basavaraj.aihole12-O360-3907',
#  'stag-dsv2-O360-3689',
#  'stag-testuserwonep-O360-3290',
#  'stag-dsv2-O360-3320',
#  'stag-stagetest-O360-2216',
#  'Btest-o360p2-O360-6711',
#  'stag-o360pilot-O360-649',
#  'stag-prodo360-O360-3794',
#  'stag-basavaraj.aihole12-O360-3804',
#  'stag-yashstage-O360-3885',
#  'stag-yashstage-O360-3810',
#  'stag-laksp-O360-2983',
#  'prod-shishir-O360-6222',
#  'stag-yashstage-O360-3909',
#  'btest-testtesto360-O360-7100',
#  'test-kritika-O360-timeline-828',
#  'stag-ramya-O360-1859',
#  'test-korade-O360-7659',
#  'stag-stagetest-O360-4217']

# %%
topicName = 'test-kritika-O360-timeline-828'
consumer.subscribe([topicName])

# %%
for msg in consumer:
    sleep(3)
    print("Topic Name=%s,Message=%s"%(msg.topic,msg.value))
# Out:
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 0}'
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 1}'
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 2}'
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 3}'
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 4}'
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 5}'
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 6}'
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 7}'
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 8}'
# Topic Name=test-kritika-O360-timeline-828,Message=b'{"number": 9}'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8132\320587029.py in <module>
# ----> 1 for msg in consumer:
#       2     sleep(3)
#       3     print("Topic Name=%s,Message=%s"%(msg.topic,msg.value))
#
# d:\OSG-AA-Products\Analytics_POD_PDP\pdp\lib\site-packages\kafka\consumer\group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# d:\OSG-AA-Products\Analytics_POD_PDP\pdp\lib\site-packages\kafka\consumer\group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# d:\OSG-AA-Products\Analytics_POD_PDP\pdp\lib\site-packages\kafka\consumer\group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# d:\OSG-AA-Products\Analytics_POD_PDP\pdp\lib\site-packages\kafka\consumer\group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# d:\OSG-AA-Products\Analytics_POD_PDP\pdp\lib\site-packages\kafka\consumer\group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# d:\OSG-AA-Products\Analytics_POD_PDP\pdp\lib\site-packages\kafka\client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# d:\OSG-AA-Products\Analytics_POD_PDP\pdp\lib\site-packages\kafka\client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# ~\AppData\Local\Programs\Python\Python37\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# ~\AppData\Local\Programs\Python\Python37\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:
