# %%
import pandas as pd
import requests
import numpy as np
import requests
from bs4 import BeautifulSoup
import re
headers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/42.0.2311.135 Safari/537.36 Edge/12.246"}

# %%
def get_pdp(URL):
    try:
        f = open("keys.txt", "r")
        r_keys = f.readlines()
        keys =[]
        for i in r_keys:
            keys.append(i[:-1])
        if URL.count("google",0,35) or URL.count("yahoo",0,35) or URL.count("bing",0,35) or URL.count("youtube",0,35) or URL.count("facebook",0,35) or URL.count("wikipedia",0,35)> 0:
            class_pdp = "search_page"
        elif len(URL) < 35:
            class_pdp = "skipped"
        elif all(x in URL for x in ['amazon','/gp/aw/d/']) or \
            all(x in URL for x in ['amazon','/dp/']) or \
            all(x in URL for x in ['target','/p/']) or \
            all(x in URL for x in ['walmart','/ip/']) or \
            all(x in URL for x in ['walmart','track']):
            class_pdp = "YES"
        elif all(x in URL for x in ['amazon','/stores/']) or \
            all(x in URL for x in ['target','/b/']) or \
            all(x in URL for x in ['target','/c/']) or \
            all(x in URL for x in ['walmart','browse']) or \
            all(x in URL for x in ['walmart','/cp']) or \
            all(x in URL for x in ['target','searchTerm']) or \
            all(x in URL for x in ['walmart','search']) or \
            all(x in URL for x in ['amazon','/goldbox']) or \
            all(x in URL for x in ['amazon','/offers']) or \
            all(x in URL for x in ['amazon','/angebot']) or \
            all(x in URL for x in ['target','/top-deals']) or \
            all(x in URL for x in ['target','/circle']) or \
            all(x in URL for x in ['walmart','/m']) or \
            all(x in URL for x in ['walmart','/deals']) or \
            all(x in URL for x in ['amazon','Best-Sellers']) or \
            all(x in URL for x in ['amazon','/ask','/questions']) or \
            all(x in URL for x in ['amazon','/product-reviews/']) or \
            all(x in URL for x in ['amazon','/c/ref=mw_dp_buy_crt']) or \
            all(x in URL for x in ['amazon','/cart/']) or \
            all(x in URL for x in ['amazon','/huc/view.html?']) or \
            all(x in URL for x in ['target','/co-cart']) or \
            all(x in URL for x in ['target','/cart']) or \
            all(x in URL for x in ['amazon','bestsellers','Best-Sellers']):
            class_pdp = "Other_pages"
        else:
            HEADERS = ({'User-Agent':'Mozilla/5.0 (X11; Linux x86_64)AppleWebKit/537.36 (KHTML, like Gecko)Chrome/44.0.2403.157 Safari/537.36','Accept-Language': 'en-US, en;q=0.5'})
            webpage = requests.get(URL, headers=HEADERS, timeout=25)
            soup = BeautifulSoup(webpage.content, "html5lib")
            text = soup.find_all(text=True)
            if text == None:
                class_pdp = "No Data"
            else:
                new = []
                for i in text:
                    new.append(i.lower())
                    mystr =" ".join(new)
                pdp = [i for i in new if i in keys]
                if len(pdp) > 0 and len(pdp)< 10:
                    class_pdp = "YES"
                else:
                    class_pdp = "NO"
    except Exception as e:
        print(e)
        class_pdp = "error or timeout"
    return class_pdp

# %%
df = pd.read_csv('data1859.csv')
url_list = df['URL'].to_list()
urls = url_list[:10871]

# %%
for URL in urls:
    pdp_tag = get_pdp(URL)
    f = open("pdp_tags_2.txt", "a+")
    f.write(pdp_tag + "\n")
    f.close()

# %%
f = open("pdp_tags_2.txt", "r")
pdp_tag = f.readlines()

pdp =[]
for i in pdp_tag:
    pdp.append(i[:-1])

len(pdp)
# Out:
# 4593

# %%
df['PDP_tag'] = pdp
df.to_csv('data1859_ped.csv', index=False)

# %%
new_df
# Out:
#                                           Path Analysis  PDP Flag      PDP_tag
# 0                               https://www.target.com/       0.0      skipped
# 1      https://www.target.com/s?searchTerm=hair+removal       0.0  Other_pages
# 2     https://www.target.com/p/spa-sciences-sima-son...       1.0          YES
# 3     https://www.amazon.com/s?crid=1TL9445LWNRYU&k=...       0.0           NO
# 4     https://www.amazon.com/Philips-Norelco-Shaver-...       1.0          YES
# ...                                                 ...       ...          ...
# 7030  https://www.amazon.com/ap/signin?openid.assoc_...       0.0           NO
# 7031  https://www.amazon.com/Finishing-Touch-Flawles...       1.0          YES
# 7032  https://www.amazon.com/Finishing-Touch-Flawles...       1.0          YES
# 7033  https://www.amazon.com/Finishing-Touch-Flawles...       1.0          YES
# 7034                                https://amazon.com/       0.0      skipped
#
# [7035 rows x 3 columns]

# %%
new_df.to_csv('predicted2.csv', index=False)

# %%
URL = "https://www.noon.com/uae-ar/sheet-mask-regenerist-micro-sculpting-clear/N44022186A/p/?o=c5186ef3ae9611ce"

try:
    f = open("keys.txt", "r",encoding='utf-8')
    r_keys = f.readlines()
    keys =[]
    for i in r_keys:
        keys.append(i[:-1])
    if URL.count("google",0,35) or URL.count("yahoo",0,35) or URL.count("bing",0,35) or URL.count("youtube",0,35) or URL.count("facebook",0,35) or URL.count("wikipedia",0,35)> 0:
        class_pdp = "search_page"
    elif len(URL) < 35:
        class_pdp = "skipped"
    elif all(x in URL for x in ['amazon','/gp/aw/d/']) or \
        all(x in URL for x in ['amazon','/dp/']) or \
        all(x in URL for x in ['target','/p/']) or \
        all(x in URL for x in ['walmart','/ip/']) or \
        all(x in URL for x in ['walmart','track']):
        class_pdp = "YES"
    elif all(x in URL for x in ['amazon','/stores/']) or \
        all(x in URL for x in ['target','/b/']) or \
        all(x in URL for x in ['target','/c/']) or \
        all(x in URL for x in ['walmart','browse']) or \
        all(x in URL for x in ['walmart','/cp']) or \
        all(x in URL for x in ['target','searchTerm']) or \
        all(x in URL for x in ['walmart','search']) or \
        all(x in URL for x in ['amazon','/goldbox']) or \
        all(x in URL for x in ['amazon','/offers']) or \
        all(x in URL for x in ['amazon','/angebot']) or \
        all(x in URL for x in ['target','/top-deals']) or \
        all(x in URL for x in ['target','/circle']) or \
        all(x in URL for x in ['walmart','/m']) or \
        all(x in URL for x in ['walmart','/deals']) or \
        all(x in URL for x in ['amazon','Best-Sellers']) or \
        all(x in URL for x in ['amazon','/ask','/questions']) or \
        all(x in URL for x in ['amazon','/product-reviews/']) or \
        all(x in URL for x in ['amazon','/c/ref=mw_dp_buy_crt']) or \
        all(x in URL for x in ['amazon','/cart/']) or \
        all(x in URL for x in ['amazon','/huc/view.html?']) or \
        all(x in URL for x in ['target','/co-cart']) or \
        all(x in URL for x in ['target','/cart']) or \
        all(x in URL for x in ['amazon','bestsellers','Best-Sellers']):
        class_pdp = "Other_pages"
    else:
        HEADERS = ({'User-Agent':'Mozilla/5.0 (X11; Linux x86_64)AppleWebKit/537.36 (KHTML, like Gecko)Chrome/44.0.2403.157 Safari/537.36','Accept-Language': 'en-US, en;q=0.5'})
        webpage = requests.get(URL, headers=HEADERS, timeout=25)
        soup = BeautifulSoup(webpage.content, "html5lib",from_encoding='utf-8')
        text = soup.find_all(text=True)
        if text == None:
            class_pdp = "No Data"
        else:
            new = []
            for i in text:
                new.append(i.lower())
            pdp = [i for i in new if i in keys]
            if len(pdp) > 0 and len(pdp)< 10:
                class_pdp = "YES"
            else:
                class_pdp = "NO"
except Exception as e:
    print(e)
    class_pdp = "error or timeout"

print(pdp)
# Out:
# ['إضافة إلى عربة التسوق']

# %%
URL = "https://www.abigo.com/"
HEADERS = ({'User-Agent':'Mozilla/5.0 (X11; Linux x86_64)AppleWebKit/537.36 (KHTML, like Gecko)Chrome/44.0.2403.157 Safari/537.36','Accept-Language': 'en-US, en;q=0.5'})
webpage = requests.get(URL, headers=HEADERS, timeout=25)
soup = BeautifulSoup(webpage.content, "html5lib")
text = soup.find_all(text=True)
text
# Out:
# ['html',
#  '\n\n\t',
#  '\n\t',
#  '\n\t',
#  '\n\t',
#  '\n\t',
#  '\n\n\t\t\t',
#  ' OneTrust Cookies Consent Notice start for www.abigo.com ',
#  '\n\t\t',
#  '\n\t\t',
#  '\n\t\t',
#  '\n\t\tfunction OptanonWrapper() {  \n\n\t\tconst cookieSettingsBtn = document.getElementById("onetrust-pc-btn-handler");\n\t\tconst acceptBtn = document.getElementById("onetrust-accept-btn-handler");\n\t\tconst declineBtn = document.querySelector("button#onetrust-reject-all-handler");\n\t\t\n\t\tconst btnContainer = document.getElementById("onetrust-button-group");\n\t\tbtnContainer.insertBefore(acceptBtn, cookieSettingsBtn)\n\t\tbtnContainer.insertBefore(declineBtn, cookieSettingsBtn)\n\t\t}\n\t\t',
#  '\n\t\t',
#  ' OneTrust Cookies Consent Notice end for www.abigo.com ',
#  '\n\t\n\t\n  ',
#  '\n\t',
#  '\n\n\t',
#  ' The above 3 meta tags *must* come first in the head; any other head content must come *after* these tags ',
#  '\n\t',
#  "window.themeUrl='https://www.abigo.com/wp-content/themes/abigo2022';",
#  '\n\t',
#  '\n/*! modernizr 3.5.0 (Custom Build) | MIT *\n * https://modernizr.com/download/?-setclasses-shiv !*/\n!function(e,n,t){function a(e,n){return typeof e===n}function o(){var e,n,t,o,r,c,l;for(var f in s)if(s.hasOwnProperty(f)){if(e=[],n=s[f],n.name&&(e.push(n.name.toLowerCase()),n.options&&n.options.aliases&&n.options.aliases.length))for(t=0;t<n.options.aliases.length;t++)e.push(n.options.aliases[t].toLowerCase());for(o=a(n.fn,"function")?n.fn():n.fn,r=0;r<e.length;r++)c=e[r],l=c.split("."),1===l.length?Modernizr[l[0]]=o:(!Modernizr[l[0]]||Modernizr[l[0]]instanceof Boolean||(Modernizr[l[0]]=new Boolean(Modernizr[l[0]])),Modernizr[l[0]][l[1]]=o),i.push((o?"":"no-")+l.join("-"))}}function r(e){var n=l.className,t=Modernizr._config.classPrefix||"";if(f&&(n=n.baseVal),Modernizr._config.enableJSClass){var a=new RegExp("(^|\\\\s)"+t+"no-js(\\\\s|$)");n=n.replace(a,"$1"+t+"js$2")}Modernizr._config.enableClasses&&(n+=" "+t+e.join(" "+t),f?l.className.baseVal=n:l.className=n)}var i=[],s=[],c={_version:"3.5.0",_config:{classPrefix:"",enableClasses:!0,enableJSClass:!0,usePrefixes:!0},_q:[],on:function(e,n){var t=this;setTimeout(function(){n(t[e])},0)},addTest:function(e,n,t){s.push({name:e,fn:n,options:t})},addAsyncTest:function(e){s.push({name:null,fn:e})}},Modernizr=function(){};Modernizr.prototype=c,Modernizr=new Modernizr;var l=n.documentElement,f="svg"===l.nodeName.toLowerCase();f||!function(e,n){function t(e,n){var t=e.createElement("p"),a=e.getElementsByTagName("head")[0]||e.documentElement;return t.innerHTML="x<style>"+n+"</style>",a.insertBefore(t.lastChild,a.firstChild)}function a(){var e=E.elements;return"string"==typeof e?e.split(" "):e}function o(e,n){var t=E.elements;"string"!=typeof t&&(t=t.join(" ")),"string"!=typeof e&&(e=e.join(" ")),E.elements=t+" "+e,l(n)}function r(e){var n=y[e[g]];return n||(n={},v++,e[g]=v,y[v]=n),n}function i(e,t,a){if(t||(t=n),u)return t.createElement(e);a||(a=r(t));var o;return o=a.cache[e]?a.cache[e].cloneNode():p.test(e)?(a.cache[e]=a.createElem(e)).cloneNode():a.createElem(e),!o.canHaveChildren||h.test(e)||o.tagUrn?o:a.frag.appendChild(o)}function s(e,t){if(e||(e=n),u)return e.createDocumentFragment();t=t||r(e);for(var o=t.frag.cloneNode(),i=0,s=a(),c=s.length;c>i;i++)o.createElement(s[i]);return o}function c(e,n){n.cache||(n.cache={},n.createElem=e.createElement,n.createFrag=e.createDocumentFragment,n.frag=n.createFrag()),e.createElement=function(t){return E.shivMethods?i(t,e,n):n.createElem(t)},e.createDocumentFragment=Function("h,f","return function(){var n=f.cloneNode(),c=n.createElement;h.shivMethods&&("+a().join().replace(/[\\w\\-:]+/g,function(e){return n.createElem(e),n.frag.createElement(e),\'c("\'+e+\'")\'})+");return n}")(E,n.frag)}function l(e){e||(e=n);var a=r(e);return!E.shivCSS||f||a.hasCSS||(a.hasCSS=!!t(e,"article,aside,dialog,figcaption,figure,footer,header,hgroup,main,nav,section{display:block}mark{background:#FF0;color:#000}template{display:none}")),u||c(e,a),e}var f,u,d="3.7.3",m=e.html5||{},h=/^<|^(?:button|map|select|textarea|object|iframe|option|optgroup)$/i,p=/^(?:a|b|code|div|fieldset|h1|h2|h3|h4|h5|h6|i|label|li|ol|p|q|span|strong|style|table|tbody|td|th|tr|ul)$/i,g="_html5shiv",v=0,y={};!function(){try{var e=n.createElement("a");e.innerHTML="<xyz></xyz>",f="hidden"in e,u=1==e.childNodes.length||function(){n.createElement("a");var e=n.createDocumentFragment();return"undefined"==typeof e.cloneNode||"undefined"==typeof e.createDocumentFragment||"undefined"==typeof e.createElement}()}catch(t){f=!0,u=!0}}();var E={elements:m.elements||"abbr article aside audio bdi canvas data datalist details dialog figcaption figure footer header hgroup main mark meter nav output picture progress section summary template time video",version:d,shivCSS:m.shivCSS!==!1,supportsUnknownElements:u,shivMethods:m.shivMethods!==!1,type:"default",shivDocument:l,createElement:i,createDocumentFragment:s,addElements:o};e.html5=E,l(n),"object"==typeof module&&module.exports&&(module.exports=E)}("und ...
#  '\n\n\t',
#  ' HTML5 shim and Respond.js for IE8 support of HTML5 elements and media queries ',
#  '\n\t',
#  " WARNING: Respond.js doesn't work if you view the page via file:// ",
#  '\n\t',
#  '[if lt IE 9]>\n\t  <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>\n\t  <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>\n\t<![endif]',
#  '\n\n\n\t\t\t',
#  ' Google Tag Manager ',
#  '\n\t\t',
#  "(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\n\t\tnew Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],\n\t\tj=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\n\t\t'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\n\t\t})(window,document,'script','dataLayer','GTM-THL9F9R');",
#  '\n\t\t',
#  ' End Google Tag Manager ',
#  '\n\t\n\t',
#  '\n',
#  '\n',
#  '\n',
#  "\nbody{--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--duotone--dark-grayscale: url('#wp-duotone-dark-grayscale');--wp--preset--duotone--grayscale: url('#wp-duotone-grayscale');--wp--preset--duotone--purple-yellow: url('#wp-duotone-purple-yellow');--wp--preset--duotone--blue-red: url('#wp-duotone-blue-red');--wp--preset--duotone--midnight: url('#wp-duotone-midnight');--wp--preset--duotone--magenta-yellow: url('#wp-duotone-magenta-yellow');--wp--preset--duotone--purple-green: url('#wp-duotone-purple-green');--wp--preset--duotone--blue-orange: url('#wp-duotone-blue-orange');--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.has-pale-pink-color{color: var(--wp--preset--color--pale-pink) !important;}.has-vivid-red-color{color: var(--wp--preset--color--vivid-red) !important;}.has-luminous-vivid-orange-color{color: var(--wp--preset--color--luminous-vivid-orange) !important;}.has-luminous-vivid-amber-color{color: var(--wp--preset--color--luminous-vivid-amber) !important;}.has-light-green-cyan-color{color: var(--wp--preset--color--light-green-cyan) !important;}.has-vivid-green-cyan-color{color: var(--wp--preset--color--vivid-green-cyan) !important;}.has-pale-cyan-blue-color{color: var(--wp--preset--color--pale-cyan-blue) !important;}.has-vivid-cyan-blue-color{color: var(--wp--preset--color--vivid-cyan-blue) !important;}.has-vivid-purple-color{color: var(--wp--preset--color--vivid-purple) !important;}.has-black-background-color{background-color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-background-color{background-color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-background-color{background-color: v ...
#  '\n',
#  '\n',
#  '\n',
#  '\n/* <![CDATA[ */\nvar my_ajax_object = {"ajax_url":"https:\\/\\/www.abigo.com\\/wp-admin\\/admin-ajax.php"};\n/* ]]> */\n',
#  '\n',
#  '\n',
#  '\n',
#  ' \n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n\t\t',
#  '\n\t\t\tsup {\n\tline-height: 1;\n}\n\ntable {\n\tmargin: 1rem 0 4rem;\n\ttext-align: left;\n}\ntable th {\n\tbackground: #00005a;\n\tcolor: #fff;\n\tpadding: 0.75rem 1rem;\n\tfont-size: 0.875rem;\n\tfont-weight: 600;\n}\ntable td {\n\tpadding: 0.75rem 1rem;\n\tfont-size: 0.875rem;\n}\ntbody tr:nth-child(odd) {\n\tbackground: #f3f3f3;\n}\ntable th:first-child {\n    border-top-left-radius: 3px;\n}\ntable th:last-child {\n    border-top-right-radius: 3px;\n}\ntable td:first-child {\n    font-weight: 600;\n}\t\t',
#  '\n\t\t\n  ',
#  '\n  ',
#  '\n',
#  '\n\t\t\n\t',
#  '\n\t\t\t\t\t\n',
#  '\n\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'Select market: ',
#  'Global',
#  '\n\t\t\t\t\t\t\t\t\t\t\n\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t',
#  'Global',
#  '\n\t\t\t\t\t',
#  '\n\t\t\t\t\t',
#  '\n\t\t\t\t\t\t',
#  'Sweden',
#  '\n\t\t\t\t\t',
#  '\n\t\t\t\t\t\n\t\t\t',
#  '\n\t\t',
#  '\n\t\n\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  'Home',
#  '\n\t\t\t',
#  '\n\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  'About us',
#  '\n\t\t\t',
#  '\n\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  'Career',
#  '\n\t\t\t',
#  '\n\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  'Contact',
#  '\n\t\t\t',
#  '\n\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t',
#  '\n\t\n\t',
#  '\n\t\t',
#  'Abigo Medical AB is a part of ',
#  '\n\t',
#  '\n',
#  '\t\t\t',
#  '\n\t',
#  '\n\t\t\t\t\t\n\n',
#  '\n\t',
#  '\n\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'Select market:',
#  'Global',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t',
#  'Global',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t',
#  'Sweden',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t\t\t',
#  'Abigo Medical - an Essity Company ',
#  '\n\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t',
#  '\n\t',
#  '\n\t',
#  '\n\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  'Home',
#  '\n\t\t\t',
#  '\n\n\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  'About us',
#  '\n\t\t\t',
#  '\n\n\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  'Career',
#  '\n\t\t\t',
#  '\n\n\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  'Contact',
#  '\n\t\t\t',
#  '\n\n\t\t\t',
#  '\n\t\t\t\n\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  '\n\t\t',
#  '\n\t',
#  '\n\t',
#  '\n\n\t\t\n\t\t',
#  '\n\t\t\t\n\t\t\t\t\t\t\t',
#  '\n\t',
#  '\n      \n\t  ',
#  '\n\t\t\n\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t\t\t',
#  '\n\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'Abigo Medical',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'A global life science company with focus on improving people’s health and well-being',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'Read more',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t',
#  '\n\t\t\t\t',
#  '\n\n\t\t\t\t\n\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t      ',
#  '\n\n      ',
#  '\n    ',
#  '\n',
#  '\n\t',
#  '\n\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t',
#  'We are dedicated to improving well-being through leading hygiene and health solutions.',
#  '\n\t\t\t\t\n\t\t\t',
#  '\n\t\t',
#  '\n\t',
#  '\n',
#  '\n',
#  '\n\t',
#  '\n\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  'Abigo Medical - an Essity company',
#  '\n\t\t\t\t\t\t\t\t\t\t',
#  'Abigo Medical is a Swedish life science company founded in 1989. Since 2021, Abigo Medical is owned by the global hygiene and health company ',
#  'Essity',
#  ' and part of Business Area Health and Medical. We are dedicated to improving well-being through leading hygiene and health solutions.',
#  '\n\n\t\t\t\t\t\t\t\t\t\t\t',
#  'Read more',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t',
#  '\n\t',
#  '\n',
#  '\n\n\n',
#  '\n\t',
#  '\n\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  'Sorbact® wound dressings against infections',
#  '\n\t\t\t\t\t\t\t\t\t\t',
#  'Abigo Medical’s focus is development and manufacturing of advanced wound management products. Based on the unique Sorbact',
#  '®',
#  ' Technology, Sorbact',
#  '®',
#  ' dressings safely removes bacteria to prevent and treat infections without releasing active agents into the wound.',
#  '\n\n\t\t\t\t\t\t\t\t\t\t\t',
#  'Read more',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t',
#  '\n\t',
#  '\n',
#  '\n\n\n',
#  '\n\t',
#  '\n\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t',
#  '\n\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  'Contributing to a sustainable society',
#  '\n\t\t\t\t\t\t\t\t\t\t',
#  'We work with sustainability throughout our business, from risk reduction to sustainable innovation and value creation. We continuously strive to reduce our climate impact and think sustainability in everything we do from sourcing of material to energy consumption.',
#  '\n\n\t\t\t\t\t\t\t\t\t\t\t',
#  'Read more',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t',
#  '\n\t',
#  '\n',
#  '\n\n\t',
#  '\n\t\t\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t',
#  '×',
#  '\n\t\t',
#  '\n\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\n\t\t\t\t\t',
#  '\n\t',
#  '\n\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t\n\t\t\t\t',
#  '\t\n\t\t\t\t\t',
#  '\n\t\t\t\t',
#  '\n\n\t\t\t\t',
#  '\t\n\t\t\t\t\t',
#  'Abigo Medical is a Swedish life science company founded in 1989. Since 2021, Abigo Medical is owned by the global hygiene and health company ',
#  'Essity',
#  '.',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t',
#  '\n\n\t\t\t\t',
#  '\n\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'About us',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'Career',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'Contact',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'Privacy policy',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  'Cookie policy',
#  '\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t\t\t\t\t\t\t\t',
#  '\n\t\t\t\t',
#  '\n\n\t\t\t\t',
#  '\n\t\t\t\t\t',
#  'ABIGO Medical AB',
#  '\nEkonomivägen 5',
#  '\nSE-436 33 Askim, Sweden',
#  '\n\t\t\t\t\t',
#  '+46 31 748 49 50',
#  '\n\t\t\t\t\t',
#  'info@abigo.com',
#  '\n\t\t\t\t',
#  '\n\n\t\t\t',
#  '\n\t\t',
#  '\n\t',
#  '\n\t\n\t',
#  '\n\t\t',
#  '\n\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t\t\t',
#  'Copyright © 2022 ABIGO Medical AB. All rights reserved.',
#  '\n\t\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t\t\t',
#  '\n\t\t\t\t',
#  '\n\t\t\t',
#  '\n\t\t',
#  '\n\t',
#  '\n',
#  '\t\t\t',
#  '\n',
#  '\n    \n    ',
#  '\n      ',
#  '\n          ',
#  'Unsupported browser',
#  '\n          ',
#  "This site probably won't work great in Internet Explorer. We generally only support the recent versions of major browsers like Chrome, Firefox, Safari and Edge.",
#  '\n\n          ',
#  '\n            ',
#  '×',
#  '\n          ',
#  '\n      ',
#  '\n    ',
#  '\n\n    ',
#  '\n      /* Sample function that returns boolean in case the browser is Internet Explorer*/\n      function isIE() {\n        ua = navigator.userAgent;\n        var is_ie = ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;\n        return is_ie; \n      }\n      /* Create an alert to show if the browser is IE or not */\n      if (isIE()){\n        jQuery( window ).on( "load", function() {\n          jQuery(\'#browser-modal\').show();\n        });\n\n        jQuery(\'#browser-modal .close-button\').click(function() {\n          jQuery(\'#browser-modal\').hide();\n        });\n      }\n    ',
#  '\n\n    \n\t',
#  '\n    ',
#  '\n  \n']
